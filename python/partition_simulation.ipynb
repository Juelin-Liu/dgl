# %%
import nvtx
import torch.multiprocessing
import torch.nn.functional as F
import torchmetrics.functional as MF
import torch.distributed as dist
import gc, os
import argparse
import torch
import dgl
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.multiprocessing import spawn
from dgl.utils import pin_memory_inplace, gather_pinned_tensor_rows
from torch import Tensor
from dgl.heterograph import DGLBlock
from dgl.utils import pin_memory_inplace
from libra.util import load_dgl_graph, load_idx_split
from libra.timer import Timer
from libra.count_profiler import CountProfiler

# %%
# def load_partition_map(in_dir:str, is_pruned: bool, graph_name:str, world_size:int, mode:str, bal:str, is32: bool):
#     assert(mode in ["edge", "node", "samp"])
#     assert(bal in ["xbal", "bal"])
#     prefix = "pruned_" if is_pruned else ""
#     partition_map = torch.load(os.path.join(in_dir, f"{prefix}{graph_name}_w{world_size}_{mode}_{bal}.pt"))
#     if is32:
#         return partition_map.type(torch.int32)
#     else:
#         return partition_map.type(torch.int64)

# device = 0
# cur_dir = os.getcwd()
# cnt_dir = os.path.join(cur_dir, "cnt")
# graph_name = "com-friendster"
# data_dir = "/data/juelin/dataset/SNAP/"
# is_pruned = True
# prefix = "pruned_" if is_pruned else ""
    
# in_dir = os.path.join(data_dir, graph_name)
# train_idx, test_idx, valid_idx = load_idx_split(in_dir, is32=True)
# train_idx = train_idx.to(device)

# graph = load_dgl_graph(in_dir, is32=True, wsloop=True)
# v_num = graph.num_nodes()
# e_num = graph.num_edges()
# graph.create_formats_()
# graph.pin_memory_()
# print(f"{graph_name=} {v_num=} {e_num=}")

# %%
# pid_dir = os.path.join(cur_dir, "partition_ids")
# mode = "samp"
# partition_map_bal = load_partition_map(in_dir=pid_dir, is_pruned=is_pruned, graph_name=graph_name, world_size=4, mode=mode, bal="bal", is32=True).to(device)
# partition_map_xbal = load_partition_map(in_dir=pid_dir, is_pruned=is_pruned, graph_name=graph_name, world_size=4, mode=mode, bal="xbal", is32=True).to(device)
# partition_map_rand = torch.randint(0, 4, (v_num,), dtype = torch.int32).to(device)

# %%
# profiler = CountProfiler(partition_map_bal, partition_map_xbal, partition_map_rand)
# timer = Timer()
# epoch_num = 1
# num_edges = 0
# step = 0
# print(f"start sampling on graph {graph_name}")
# graph_sampler = dgl.dataloading.NeighborSampler(fanouts=[20, 20, 20])
# dataloader = dgl.dataloading.DataLoader(
#     graph=graph,               # The graph
#     indices=train_idx,         # The node IDs to iterate over in minibatches
#     graph_sampler=graph_sampler,     # The neighbor sampler
#     device=device,      # Put the sampled MFGs on CPU or GPU
#     use_ddp=False, # enable ddp if using mutiple gpus
#     # The following arguments are inherited from PyTorch DataLoader.
#     batch_size=1024,    # Batch size
#     shuffle=True,       # Whether to shuffle the nodes for every epoch
#     drop_last=False,    # Whether to drop the last incomplete batch
#     use_uva=graph.is_pinned(),
#     num_workers=0,
# )

# for epoch in range(epoch_num):
#     for input_nodes, output_nodes, blocks in dataloader:
#         step += 1
#         for layer, block in enumerate(blocks):
#             num_edges += block.num_edges()

#             src, dst = block.all_edges()
#             src = input_nodes[src]
#             dst = input_nodes[dst]
#             profiler.add_edges(src, dst)

#             unique_src = block.srcnodes()
#             unique_src = input_nodes[unique_src]
#             profiler.add_src(unique_src)

#             unique_dst = block.dstnodes()
#             unique_dst = input_nodes[unique_dst]
#             profiler.add_dst(unique_dst)

#         if step % 100 == 0:
#             print(f"{step=} {num_edges=}")
# print(f"duration = {timer.duration()} s")
# profiler.save(path=os.path.join(cnt_dir, f"{prefix}{graph_name}_{mode}.pt"))

# %%
def load_partition_map(in_dir:str, is_pruned: bool, graph_name:str, world_size:int, mode:str, bal:str, is32: bool):
    assert(mode in ["edge", "node", "samp"])
    assert(bal in ["xbal", "bal"])
    prefix = "pruned_" if is_pruned else ""
    partition_map = torch.load(os.path.join(in_dir, f"{prefix}{graph_name}_w{world_size}_{mode}_{bal}.pt"))
    if is32:
        return partition_map.type(torch.int32)
    else:
        return partition_map.type(torch.int64)

def prof(graph_name: str, data_dir: str, is_pruned: bool):
    device = 0
    cur_dir = os.getcwd()
    cnt_dir = os.path.join(cur_dir, "cnt")
    prefix = "pruned_" if is_pruned else ""

    in_dir = os.path.join(data_dir, graph_name)
    train_idx, test_idx, valid_idx = load_idx_split(in_dir, is32=True)
    train_idx = train_idx.to(device)

    graph = load_dgl_graph(in_dir, is32=True, wsloop=True)
    v_num = graph.num_nodes()
    e_num = graph.num_edges()
    graph.create_formats_()
    graph.pin_memory_()
    print(f"{graph_name=} {v_num=} {e_num=}")
    pid_dir = os.path.join(cur_dir, "partition_ids")
    partition_map_rand = torch.randint(0, 4, (v_num,), dtype = torch.int32).to(device)
    for mode in ["samp", "node", "edge"]:
        partition_map_bal = load_partition_map(in_dir=pid_dir, is_pruned=is_pruned, graph_name=graph_name, world_size=4, mode=mode, bal="bal", is32=True).to(device)
        partition_map_xbal = load_partition_map(in_dir=pid_dir, is_pruned=is_pruned, graph_name=graph_name, world_size=4, mode=mode, bal="xbal", is32=True).to(device)
        profiler = CountProfiler(partition_map_bal, partition_map_xbal, partition_map_rand)
        timer = Timer()
        epoch_num = 1
        num_edges = 0
        step = 0
        print(f"start sampling on graph {graph_name}")
        graph_sampler = dgl.dataloading.NeighborSampler(fanouts=[20, 20, 20])
        dataloader = dgl.dataloading.DataLoader(
            graph=graph,               # The graph
            indices=train_idx,         # The node IDs to iterate over in minibatches
            graph_sampler=graph_sampler,     # The neighbor sampler
            device=device,      # Put the sampled MFGs on CPU or GPU
            use_ddp=False, # enable ddp if using mutiple gpus
            # The following arguments are inherited from PyTorch DataLoader.
            batch_size=1024,    # Batch size
            shuffle=True,       # Whether to shuffle the nodes for every epoch
            drop_last=False,    # Whether to drop the last incomplete batch
            use_uva=graph.is_pinned(),
            num_workers=0,
        )

        for epoch in range(epoch_num):
            for input_nodes, output_nodes, blocks in dataloader:
                step += 1
                for layer, block in enumerate(blocks):
                    num_edges += block.num_edges()

                    src, dst = block.all_edges()
                    src = input_nodes[src]
                    dst = input_nodes[dst]
                    profiler.add_edges(src, dst)

                    unique_src = block.srcnodes()
                    unique_src = input_nodes[unique_src]
                    profiler.add_src(unique_src)

                    unique_dst = block.dstnodes()
                    unique_dst = input_nodes[unique_dst]
                    profiler.add_dst(unique_dst)

                if step % 100 == 0:
                    print(f"{step=} {num_edges=}")
        print(f"duration = {timer.duration()} s")
        profiler.save(path=os.path.join(cnt_dir, f"{prefix}{graph_name}_{mode}.pt"))

# %%
dataset = {
    "ogbn-products":   "/data/juelin/dataset/OGBN/processed",
    "ogbn-papers100M": "/data/juelin/dataset/OGBN/processed",
    "com-orkut": "/data/juelin/dataset/SNAP/",
    "com-friendster": "/data/juelin/dataset/SNAP/"
}

for graph_name, data_dir in dataset.items():
    for is_pruned in [True, False]:
        prof(graph_name, data_dir, is_pruned)
        prof(graph_name, data_dir, is_pruned)
# Out:
# graph_name='ogbn-products' v_num=2449029 e_num=126167053
# start sampling on graph ogbn-products
# step=100 num_edges=539207102
# duration = 11.111 s
# start sampling on graph ogbn-products
# step=100 num_edges=539009834
# duration = 11.06 s
# start sampling on graph ogbn-products
# step=100 num_edges=539079289
# duration = 11.103 s
# graph_name='ogbn-products' v_num=2449029 e_num=126167053
# start sampling on graph ogbn-products
# step=100 num_edges=538964659
# duration = 11.13 s
# start sampling on graph ogbn-products
# step=100 num_edges=538629614
# duration = 11.164 s
# start sampling on graph ogbn-products
# step=100 num_edges=539014129
# duration = 11.159 s
# graph_name='ogbn-products' v_num=2449029 e_num=126167053
# start sampling on graph ogbn-products
# step=100 num_edges=538901004
# duration = 11.63 s
# start sampling on graph ogbn-products
# step=100 num_edges=538914203
# duration = 11.363 s
# start sampling on graph ogbn-products
# step=100 num_edges=538867874
# duration = 11.336 s
# graph_name='ogbn-products' v_num=2449029 e_num=126167053
# start sampling on graph ogbn-products
# step=100 num_edges=539026880
# duration = 11.213 s
# start sampling on graph ogbn-products
# step=100 num_edges=539446249
# duration = 11.68 s
# start sampling on graph ogbn-products
# step=100 num_edges=539391071
# duration = 11.453 s
# graph_name='ogbn-papers100M' v_num=111059956 e_num=1726745828
# start sampling on graph ogbn-papers100M
# step=100 num_edges=64845206
# step=200 num_edges=130167835
# step=300 num_edges=195203309
# step=400 num_edges=260214414
# step=500 num_edges=325094617
# step=600 num_edges=390060371
# step=700 num_edges=454807766
# step=800 num_edges=519892089
# step=900 num_edges=585266676
# step=1000 num_edges=650175659
# step=1100 num_edges=715405244
# duration = 21.169 s
# start sampling on graph ogbn-papers100M
# step=100 num_edges=64940922
# step=200 num_edges=129495370
# step=300 num_edges=194736256
# step=400 num_edges=260157334
# step=500 num_edges=325321734
# step=600 num_edges=390366645
# step=700 num_edges=455558239
# step=800 num_edges=520490834
# step=900 num_edges=585545186
# step=1000 num_edges=650442835
# step=1100 num_edges=715904030
# duration = 22.132 s
# start sampling on graph ogbn-papers100M
# step=100 num_edges=64973994
# step=200 num_edges=130191840
# step=300 num_edges=195343268
# step=400 num_edges=260022623
# step=500 num_edges=325210418
# step=600 num_edges=390018536
# step=700 num_edges=455102513
# step=800 num_edges=519778464
# step=900 num_edges=584912641
# step=1000 num_edges=650126699
# step=1100 num_edges=715609484
# duration = 21.405 s
# graph_name='ogbn-papers100M' v_num=111059956 e_num=1726745828
# start sampling on graph ogbn-papers100M
# step=100 num_edges=64993332
# step=200 num_edges=130022132
# step=300 num_edges=194877424
# step=400 num_edges=259916993
# step=500 num_edges=325347481
# step=600 num_edges=390601777
# step=700 num_edges=455664162
# step=800 num_edges=520480026
# step=900 num_edges=585746030
# step=1000 num_edges=650883032
# step=1100 num_edges=716003601
# duration = 21.293 s
# start sampling on graph ogbn-papers100M
# step=100 num_edges=65426633
# step=200 num_edges=130299591
# step=300 num_edges=195422601
# step=400 num_edges=260522367
# step=500 num_edges=325859408
# step=600 num_edges=390966249
# step=700 num_edges=455609986
# step=800 num_edges=520706263
# step=900 num_edges=585607171
# step=1000 num_edges=650777129
# step=1100 num_edges=715739301
# duration = 22.097 s
# start sampling on graph ogbn-papers100M
# step=100 num_edges=64945390
# step=200 num_edges=129878787
# step=300 num_edges=195033664
# step=400 num_edges=260027165
# step=500 num_edges=325703914
# step=600 num_edges=390933241
# step=700 num_edges=456030006
# step=800 num_edges=520623518
# step=900 num_edges=585386729
# step=1000 num_edges=650492417
# step=1100 num_edges=715722896
# duration = 21.912 s
# graph_name='ogbn-papers100M' v_num=111059956 e_num=1726745828
# start sampling on graph ogbn-papers100M
# step=100 num_edges=65362781
# step=200 num_edges=130308900
# step=300 num_edges=194948622
# step=400 num_edges=260479457
# step=500 num_edges=325660767
# step=600 num_edges=390559786
# step=700 num_edges=456181271
# step=800 num_edges=521456996
# step=900 num_edges=586435908
# step=1000 num_edges=651124746
# step=1100 num_edges=716146656
# duration = 21.208 s
# start sampling on graph ogbn-papers100M
# step=100 num_edges=64622179
# step=200 num_edges=129820739
# step=300 num_edges=195113188
# step=400 num_edges=260507925
# step=500 num_edges=325259453
# step=600 num_edges=390420124
# step=700 num_edges=455091754
# step=800 num_edges=520223798
# step=900 num_edges=585755898
# step=1000 num_edges=650891378
# step=1100 num_edges=715563834
# duration = 23.734 s
# start sampling on graph ogbn-papers100M
# step=100 num_edges=65122477
# step=200 num_edges=130613437
# step=300 num_edges=195730399
# step=400 num_edges=261015758
# step=500 num_edges=326082935
# step=600 num_edges=390738658
# step=700 num_edges=455443892
# step=800 num_edges=520771919
# step=900 num_edges=585866817
# step=1000 num_edges=651262333
# step=1100 num_edges=715991405
# duration = 22.795 s
# graph_name='ogbn-papers100M' v_num=111059956 e_num=1726745828
# start sampling on graph ogbn-papers100M
# step=100 num_edges=65442901
# step=200 num_edges=130604987
# step=300 num_edges=195145668
# step=400 num_edges=260322746
# step=500 num_edges=325186831
# step=600 num_edges=390651739
# step=700 num_edges=455637425
# step=800 num_edges=520575707
# step=900 num_edges=585653702
# step=1000 num_edges=651162187
# step=1100 num_edges=715932871
# duration = 21.32 s
# start sampling on graph ogbn-papers100M
# step=100 num_edges=64738696
# step=200 num_edges=129632106
# step=300 num_edges=194446126
# step=400 num_edges=259009401
# step=500 num_edges=324253238
# step=600 num_edges=389291111
# step=700 num_edges=454546076
# step=800 num_edges=520169090
# step=900 num_edges=585313500
# step=1000 num_edges=650344456
# step=1100 num_edges=715614755
# duration = 23.351 s
# start sampling on graph ogbn-papers100M
# step=100 num_edges=64680334
# step=200 num_edges=129751731
# step=300 num_edges=194820130
# step=400 num_edges=259972669
# step=500 num_edges=324692845
# step=600 num_edges=389801670
# step=700 num_edges=454940527
# step=800 num_edges=520277985
# step=900 num_edges=585549418
# step=1000 num_edges=650250394
# step=1100 num_edges=715461088
# duration = 22.601 s
# graph_name='com-orkut' v_num=3072627 e_num=120257710
# start sampling on graph com-orkut
# step=100 num_edges=347489504
# step=200 num_edges=695141540
# duration = 9.29 s
# start sampling on graph com-orkut
# step=100 num_edges=347240628
# step=200 num_edges=694464736
# duration = 9.14 s
# start sampling on graph com-orkut
# step=100 num_edges=346787355
# step=200 num_edges=694928069
# duration = 8.732 s
# graph_name='com-orkut' v_num=3072627 e_num=120257710
# start sampling on graph com-orkut
# step=100 num_edges=347238797
# step=200 num_edges=695463346
# duration = 8.728 s
# start sampling on graph com-orkut
# step=100 num_edges=347322805
# step=200 num_edges=694671259
# duration = 8.66 s
# start sampling on graph com-orkut
# step=100 num_edges=348410327
# step=200 num_edges=695383831
# duration = 8.338 s
# graph_name='com-orkut' v_num=3072627 e_num=120257710
# start sampling on graph com-orkut
# step=100 num_edges=347668679
# step=200 num_edges=694927183
# duration = 8.566 s
# start sampling on graph com-orkut
# step=100 num_edges=347339444
# step=200 num_edges=695196959
# duration = 8.506 s
# start sampling on graph com-orkut
# step=100 num_edges=347476152
# step=200 num_edges=695069701
# duration = 8.148 s
# graph_name='com-orkut' v_num=3072627 e_num=120257710
# start sampling on graph com-orkut
# step=100 num_edges=347319232
# step=200 num_edges=695498934
# duration = 8.576 s
# start sampling on graph com-orkut
# step=100 num_edges=347322068
# step=200 num_edges=694908132
# duration = 8.501 s
# start sampling on graph com-orkut
# step=100 num_edges=347478799
# step=200 num_edges=695304355
# duration = 8.137 s
# graph_name='com-friendster' v_num=124836180 e_num=1930903315
# start sampling on graph com-friendster
# step=100 num_edges=179689728
# step=200 num_edges=360678121
# step=300 num_edges=540814722
# step=400 num_edges=721992768
# step=500 num_edges=903300214
# step=600 num_edges=1083721299
# step=700 num_edges=1261777752
# step=800 num_edges=1443389506
# step=900 num_edges=1625475822
# step=1000 num_edges=1806208787
# step=1100 num_edges=1986407413
# step=1200 num_edges=2168029228
# step=1300 num_edges=2349549582
# duration = 37.771 s
# start sampling on graph com-friendster
# step=100 num_edges=180868711
# step=200 num_edges=360145552
# step=300 num_edges=540546011
# step=400 num_edges=722591384
# step=500 num_edges=903159655
# step=600 num_edges=1082774835
# step=700 num_edges=1264497619
# step=800 num_edges=1445665457
# step=900 num_edges=1628127586
# step=1000 num_edges=1808639413
# step=1100 num_edges=1989686639
# step=1200 num_edges=2169491948
# step=1300 num_edges=2350614525
# duration = 45.29 s
# start sampling on graph com-friendster
# step=100 num_edges=180223690
# step=200 num_edges=361816061
# step=300 num_edges=542417700
# step=400 num_edges=723936091
# step=500 num_edges=904924621
# step=600 num_edges=1085223312
# step=700 num_edges=1265090075
# step=800 num_edges=1445034844
# step=900 num_edges=1626983630
# step=1000 num_edges=1808461229
# step=1100 num_edges=1989647161
# step=1200 num_edges=2169947184
# step=1300 num_edges=2350169103
# duration = 38.86 s
# graph_name='com-friendster' v_num=124836180 e_num=1930903315
# start sampling on graph com-friendster
# step=100 num_edges=180727027
# step=200 num_edges=362272264
# step=300 num_edges=542032038
# step=400 num_edges=721692536
# step=500 num_edges=901433378
# step=600 num_edges=1082017178
# step=700 num_edges=1264242853
# step=800 num_edges=1444607665
# step=900 num_edges=1626102097
# step=1000 num_edges=1807037576
# step=1100 num_edges=1988310646
# step=1200 num_edges=2169640010
# step=1300 num_edges=2350488994
# duration = 39.627 s
# start sampling on graph com-friendster
# step=100 num_edges=180172228
# step=200 num_edges=359112822
# step=300 num_edges=540245526
# step=400 num_edges=721345216
# step=500 num_edges=902727643
# step=600 num_edges=1083803220
# step=700 num_edges=1265391709
# step=800 num_edges=1445823947
# step=900 num_edges=1627390608
# step=1000 num_edges=1807327569
# step=1100 num_edges=1987923098
# step=1200 num_edges=2168188589
# step=1300 num_edges=2350615341
# duration = 45.761 s
# start sampling on graph com-friendster
# step=100 num_edges=180371125
# step=200 num_edges=360793155
# step=300 num_edges=542401865
# step=400 num_edges=723934219
# step=500 num_edges=903772357
# step=600 num_edges=1083465457
# step=700 num_edges=1263390178
# step=800 num_edges=1445187485
# step=900 num_edges=1625796905
# step=1000 num_edges=1807474986
# step=1100 num_edges=1989071488
# step=1200 num_edges=2169292163
# step=1300 num_edges=2350423314
# duration = 39.572 s
# graph_name='com-friendster' v_num=124836180 e_num=1930903315
# start sampling on graph com-friendster
# step=100 num_edges=179989341
# step=200 num_edges=359421785
# step=300 num_edges=541960528
# step=400 num_edges=723037689
# step=500 num_edges=904669807
# step=600 num_edges=1086472169
# step=700 num_edges=1266282258
# step=800 num_edges=1446476284
# step=900 num_edges=1627524015
# step=1000 num_edges=1808045693
# step=1100 num_edges=1988360504
# step=1200 num_edges=2169441653
# step=1300 num_edges=2349876750
# duration = 38.157 s
# start sampling on graph com-friendster
# step=100 num_edges=180887021
# step=200 num_edges=362954508
# step=300 num_edges=541985540
# step=400 num_edges=723366395
# step=500 num_edges=902816397
# step=600 num_edges=1084007326
# step=700 num_edges=1265778754
# step=800 num_edges=1446116833
# step=900 num_edges=1627709194
# step=1000 num_edges=1807705532
# step=1100 num_edges=1988781993
# step=1200 num_edges=2169220589
# step=1300 num_edges=2350147195
# duration = 40.66 s
# start sampling on graph com-friendster
# step=100 num_edges=179812769
# step=200 num_edges=360430629
# step=300 num_edges=540656491
# step=400 num_edges=722534745
# step=500 num_edges=903461742
# step=600 num_edges=1085309912
# step=700 num_edges=1266039748
# step=800 num_edges=1448072719
# step=900 num_edges=1627336952
# step=1000 num_edges=1807549124
# step=1100 num_edges=1988485921
# step=1200 num_edges=2168574305
# step=1300 num_edges=2349331451
# duration = 39.793 s
# graph_name='com-friendster' v_num=124836180 e_num=1930903315
# start sampling on graph com-friendster
# step=100 num_edges=181140768
# step=200 num_edges=363274686
# step=300 num_edges=543682211
# step=400 num_edges=724788687
# step=500 num_edges=905862219
# step=600 num_edges=1087022561
# step=700 num_edges=1266729710
# step=800 num_edges=1446783963
# step=900 num_edges=1627983836
# step=1000 num_edges=1807911618
# step=1100 num_edges=1988749146
# step=1200 num_edges=2168712931
# step=1300 num_edges=2350939528
# duration = 38.469 s
# start sampling on graph com-friendster
# step=100 num_edges=182033799
# step=200 num_edges=361714143
# step=300 num_edges=541902718
# step=400 num_edges=721298325
# step=500 num_edges=903545646
# step=600 num_edges=1084841029
# step=700 num_edges=1265871884
# step=800 num_edges=1446534310
# step=900 num_edges=1627898168
# step=1000 num_edges=1808175672
# step=1100 num_edges=1989688967
# step=1200 num_edges=2170599512
# step=1300 num_edges=2350424939
# duration = 42.021 s
# start sampling on graph com-friendster
# step=100 num_edges=180587100
# step=200 num_edges=361644878
# step=300 num_edges=541755910
# step=400 num_edges=722924084
# step=500 num_edges=904952031
# step=600 num_edges=1085501556
# step=700 num_edges=1266169578
# step=800 num_edges=1448279706
# step=900 num_edges=1629535860
# step=1000 num_edges=1809776606
# step=1100 num_edges=1990237303
# step=1200 num_edges=2170156303
# step=1300 num_edges=2351011086
# duration = 41.974 s
